# %% [markdown]
# ### what_is_this_image
#
# a function for interrogating image data in python 3
#
# #### a brief demonstration

# %%
#imports

import os
import numpy as np
import cv2
from PIL import Image
import matplotlib.pyplot as plt

# %%
cwd = os.getcwd()

image_dir = cwd + os.sep + 'image_files' + os.sep

impath_1 = image_dir + 'catBWjpeg.jpg'
impath_2 = image_dir + 'dogpng.png'
impath_3 = image_dir + 'maskpng.png'
impath_4 = image_dir + 'catColor.jpg'

# %%
# various kinds of images read into python in different ways
im1 = Image.open(impath_1)
im2 = cv2.imread(impath_1)
im3 = Image.open(impath_2)
im4 = cv2.imread(impath_2)
im5 = cv2.imread(impath_3, cv2.IMREAD_GRAYSCALE)
im6 = Image.open(impath_3)
im7 = Image.open(impath_4)
im8 = cv2.imread(impath_4)
im9 = Image.open(impath_4).convert('L')

image_list = [im1, im2, im3, im4, im5, im6, im7, im8, im9]

# %%
# lets bring the function in...
from whatisthis.img_tools import what_is_this_image

# %%
for image in image_list:
    what_is_this_image(image, show = True)
# Out:
# It's a PIL image
# It's format is JPEG
# It's size is (970, 647)
# It's height is 647
# It's width is 970
# It has 3 channels
# It's mode is RGB
# It's (min,max) values are ((0, 255), (0, 255), (0, 255))
# It's an np.ndarray
# It's shape is: (647, 970, 3)
# It's dims are: 3
# It contains 3 channels
# It's size is: 1882770
# It's dtype is: uint8
# This Array's min value is 0
# This Array's max value is 255
# It's a PIL image
# It's format is PNG
# It's size is (840, 859)
# It's height is 859
# It's width is 840
# It has 4 channels
# It's mode is RGBA
# It's (min,max) values are ((32, 255), (17, 255), (9, 255), (255, 255))
# It's an np.ndarray
# It's shape is: (859, 840, 3)
# It's dims are: 3
# It contains 3 channels
# It's size is: 2164680
# It's dtype is: uint8
# This Array's min value is 9
# This Array's max value is 255
# It's an np.ndarray
# It's shape is: (1830, 1260)
# It's dims are: 2
# It contains 1 channel
# It's size is: 2305800
# It's dtype is: uint8
# This Array's min value is 0
# This Array's max value is 255
# It's a PIL image
# It's format is PNG
# It's size is (1260, 1830)
# It's height is 1830
# It's width is 1260
# It has 1 channels
# It's mode is L
# It's (min,max) values are (0, 255)
# It's a PIL image
# It's format is JPEG
# It's size is (386, 500)
# It's height is 500
# It's width is 386
# It has 3 channels
# It's mode is RGB
# It's (min,max) values are ((0, 243), (0, 239), (0, 239))
# It's an np.ndarray
# It's shape is: (500, 386, 3)
# It's dims are: 3
# It contains 3 channels
# It's size is: 579000
# It's dtype is: uint8
# This Array's min value is 0
# This Array's max value is 243
# It's a PIL image
# It's format is None
# It's size is (386, 500)
# It's height is 500
# It's width is 386
# It has 1 channels
# It's mode is L
# It's (min,max) values are (0, 239)

# %%
## here is what it looks like..
# def what_is_this_image(mystery_image, show = False):
#     if isinstance(mystery_image, np.ndarray):
#         print("It's an np.ndarray")
#         print(f"It's shape is: {mystery_image.shape}")
#         sh = mystery_image.shape
#         dims = len(mystery_image.shape)
#         print(f"It's dims are: {dims}")
#         if dims == 2:
#             print("It contains 1 channel")
#         else:
#             print(f"It contains {sh[-1]} channels")
#         print(f"It's size is: {mystery_image.size}")
#         print(f"It's dtype is: {mystery_image.dtype}")
#         print(f"This Array's min value is {np.min(mystery_image)}")
#         print(f"This Array's max value is {np.max(mystery_image)}")
#         im_type = 'A'
#     elif isinstance(mystery_image, Image.Image):
#         print("It's a PIL image")
#         print(f"It's format is {mystery_image.format}")
#         print(f"It's size is {mystery_image.size}")
#         print(f"It's height is {mystery_image.height}")
#         print(f"It's width is {mystery_image.width}")
#         n_channels = len(mystery_image.split())
#         print(f"It has {n_channels} channels")
#         print(f"It's mode is {mystery_image.mode}")
#         extrema = mystery_image.getextrema()
#         print(f"It's (min,max) values are {extrema}")
#         im_type = 'P'
#     else:
#         print("Its not a np.ndarray or a PIL image....")
#         im_type = 'U'
#     if show == True:
#         try:
#             if im_type == 'P':
#                 md = mystery_image.mode
#                 if md == 'L':
#                     plt.imshow(mystery_image, cmap = 'gray')
#                     plt.show(block = False)
#                     plt.close('all')
#                 else:
#                     plt.imshow(mystery_image)
#                     plt.show(block = False)
#                     plt.close('all')
#             elif im_type == 'A':
#                 # check channels
#                 if dims == 2:
#                     plt.imshow(mystery_image, cmap = 'gray')
#                     plt.colorbar()
#                     plt.show(block = False)
#                     plt.close('all')

#                 else:
#                     plt.imshow(mystery_image)
#                     plt.colorbar()
#                     plt.show(block = False)
#                     plt.close('all')
#             else:
#                 print('im_type == U or Unknown')
#         except:
#             print('image could not be shown with plt.imshow() ')
#     else:
#         pass
